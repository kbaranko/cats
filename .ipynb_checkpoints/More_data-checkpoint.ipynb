# %%
import pandas as pd 
from pandas import ExcelWriter
from pandas import ExcelFile
import config
db_name = 'emissions_modelling' 
import seaborn as sns
import matplotlib
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df_net = pd.read_excel('Individuals_Internet_2000-2018_Jun2019.xls')

# %%
df_net.head()
# Out:
#        Unnamed: 0  Percentage of Individuals using the Internet    Unnamed: 2  \
# 0             NaN                                    2000.000000  2001.000000
# 1     Afghanistan                                            NaN     0.004723
# 2         Albania                                       0.114097     0.325798
# 3         Algeria                                       0.491706     0.646114
# 4  American Samoa                                            NaN          NaN
#
#     Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 0  2002.000000  2003.000000  2004.000000  2005.000000  2006.000000
# 1     0.004561     0.087891     0.105809     1.224148     2.107124
# 2     0.390081     0.971900     2.420388     6.043891     9.609991
# 3     1.591641     2.195360     4.634475     5.843942     7.375985
# 4          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 8  Unnamed: 9  ...  Unnamed: 49    Unnamed: 50  Unnamed: 51  \
# 0  2007.000000     2008.00  ...   Notes 2014    Source 2014   Notes 2015
# 1     1.900000        1.84  ...          NaN  ITU estimate.          NaN
# 2    15.036115       23.86  ...          NaN  ITU estimate.          NaN
# 3     9.451191       10.18  ...          NaN  ITU estimate.          NaN
# 4          NaN         NaN  ...          NaN            NaN          NaN
#
#      Unnamed: 52  Unnamed: 53      Unnamed: 54  Unnamed: 55      Unnamed: 56  \
# 0    Source 2015   Notes 2016      Source 2016   Notes 2017      Source 2017
# 1  ITU estimate.          18+  Asia Foundation          18+  Asia Foundation
# 2  ITU estimate.          NaN    ITU estimate.          NaN    ITU estimate.
# 3  ITU estimate.          NaN    ITU Estimate.          NaN    ITU estimate.
# 4            NaN          NaN              NaN          NaN              NaN
#
#    Unnamed: 57                       Unnamed: 58
# 0   Notes 2018                       Source 2018
# 1          NaN                               NaN
# 2          NaN                               NaN
# 3          NaN  Office National des Statistiques
# 4          NaN                               NaN
#
# [5 rows x 59 columns]

# %%
df_net = df_net[['Unnamed: 0', 'Unnamed: 17']]

# %%
df_net.head()
# Out:
#           country  internet_percent_pop
# 1     Afghanistan             11.200000
# 2         Albania             66.363445
# 3         Algeria             42.945527
# 4  American Samoa                   NaN
# 5         Andorra             97.930637

# %%
df_net.rename(columns = {'Unnamed: 0':'country', 'Unnamed: 17': 'internet_percent_pop'}, inplace = True)

# %%
df_net = df_net[1:]

# %%
len(df_net)
# Out:
# 206

# %%
df_net = df_net.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
sns.distplot(df_net['internet_percent_pop'], bins = 50)

# %%
df_nrg = pd.read_excel('API_EG.USE.COMM.CL.ZS_DS2_en_excel_v2_327403.xls')

# %%
df_biz = pd.read_excel('API_IC.REG.COST.PC.ZS_DS2_en_excel_v2_323055.xls')

# %%
df_biz = df_biz[['Data Source', 'Unnamed: 60']]

# %%
df_biz.rename(columns = {'Data Source':'country', 'Unnamed: 60': 'cost_of_biz'}, inplace = True)

# %%
df_biz = df_biz[3:]

# %%
df_biz = df_biz.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
len(df_biz)
# Out:
# 235

# %%
df = df.merge(df_biz, how='inner', on='country')

# %%
df_services = pd.read_excel('API_NV.SRV.TOTL.ZS_DS2_en_excel_v2_319004.xls')

# %%
df.head()
# Out:
#    Unnamed: 0    country       gdp_usd  population  CPI  rank  GI_risk  \
# 0           0    Albania  3.087580e+10   2927090.0   36    99       35
# 1           1    Algeria  5.536240e+11  40563900.0   35   105       35
# 2           2     Angola  1.768130e+11  28852900.0   19   165       22
# 3           3  Argentina  7.994760e+11  43897900.0   40    85       35
# 4           4    Armenia  2.344670e+10   2921300.0   35   105       35
#
#      co2_mmt  gdp_capita  regulatory_quality  ...  GDP_Ag_and_Forest  \
# 0    4.22116    10548.30            0.189022  ...           19.85000
# 1  138.72300    13648.20           -1.171880  ...           12.21280
# 2   21.41700     6128.08           -1.001380  ...            9.83117
# 3  194.10000    18212.20           -0.469625  ...            6.26457
# 4    5.21980     8026.12            0.250056  ...           16.39050
#
#    petro_income  resource_income    co2_dollar  co2_kg_dollar  meat_milk_tn  \
# 0      0.853421          1.04950  1.367142e-10       0.136714       89452.0
# 1     10.046100         12.30340  2.505726e-10       0.250573      745909.0
# 2     10.168700         10.74620  1.211280e-10       0.121128      285661.0
# 3      0.552452          1.13494  2.427840e-10       0.242784     5397512.0
# 4      0.000000          4.41208  2.226241e-10       0.222624      106144.0
#
#    energy_value  internet_percent_pop  perc_renewable_energy  cost_of_biz
# 0     13.926832             66.363445              24.548050         12.5
# 1     10.784678             42.945527               0.030106         11.1
# 2     13.219101             13.000000               2.548840         20.7
# 3      9.856690             70.968981               5.501504         10.8
# 4      8.273444             64.346030              25.718264          0.9
#
# [5 rows x 25 columns]

# %%
df = pd.read_csv('thurs_data.csv')

# %%
df = df.merge(df_net, how='inner', on='country')

# %%
len(df)
# Out:
# 113

# %%
df_nrg = pd.read_excel('API_EG.USE.COMM.CL.ZS_DS2_en_excel_v2_327403.xls')

# %%
df_nrg.head()
# Out:
#          Data Source World Development Indicators  \
# 0  Last Updated Date          2019-10-16 00:00:00
# 1                NaN                          NaN
# 2       Country Name                 Country Code
# 3              Aruba                          ABW
# 4        Afghanistan                          AFG
#
#                                           Unnamed: 2         Unnamed: 3  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                     Indicator Name     Indicator Code
# 3  Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# 4  Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2      1960.0      1961.0      1962.0      1963.0      1964.0      1965.0
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    ...  Unnamed: 53  Unnamed: 54  Unnamed: 55  Unnamed: 56  Unnamed: 57  \
# 0  ...          NaN          NaN          NaN          NaN          NaN
# 1  ...          NaN          NaN          NaN          NaN          NaN
# 2  ...       2009.0       2010.0       2011.0       2012.0       2013.0
# 3  ...          NaN          NaN          NaN          NaN          NaN
# 4  ...          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       2014.0       2015.0       2016.0       2017.0       2018.0
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 63 columns]

# %%
df_nrg = df_nrg[['Data Source', 'Unnamed: 58']]

# %%
df_nrg.rename(columns = {'Data Source':'country', 'Unnamed: 58': 'perc_renewable_energy'}, inplace = True)

# %%
df_nrg = df_nrg[2:]

# %%
df_nrg = df_nrg.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
len(df_nrg)
# Out:
# 180

# %%
df_nrg.head()
# Out:
#                  country  perc_renewable_energy
# 5                 Angola               2.548840
# 6                Albania              24.548050
# 8             Arab World               0.414413
# 9   United Arab Emirates               0.096907
# 10             Argentina               5.501504

# %%
df = df.merge(df_nrg, how='inner', on='country')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'gdp_usd', 'population', 'CPI', 'rank',
#        'GI_risk', 'co2_mmt', 'gdp_capita', 'regulatory_quality',
#        'political_stability', 'accountability', 'rule_of_law',
#        'co2_mmt_capita', 'co2_kg_capita', 'GDP_Ag_and_Forest', 'petro_income',
#        'resource_income', 'co2_dollar', 'co2_kg_dollar', 'meat_milk_tn',
#        'energy_value', 'internet_percent_pop', 'perc_renewable_energy'],
#       dtype='object')

# %%
len(df)
# Out:
# 113

# %%
df_model = df[['co2_kg_dollar', 'internet_percent_pop', 'GDP_Ag_and_Forest', 'perc_renewable_energy']]

# %%
df_net_vs_co2 = df[['co2_kg_dollar', 'internet_percent_pop']]

# %%
df_model['GDP_Ag_and_Forest'] = np.log(df_model['GDP_Ag_and_Forest'] + 1)
df_model['perc_renewable_energy'] = np.log(df_model['perc_renewable_energy'] + 1)
# Out:
# /Users/kylebaranko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/kylebaranko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x_cols = ['GDP_Ag_and_Forest', 'perc_renewable_energy']

# %%
pd.plotting.scatter_matrix(df_model, figsize=(10,12));

# %%
outcome = 'co2_kg_dollar'
predictors = df_net_vs_co2.drop('co2_kg_dollar', axis=1)
pred_sum = "+".join(predictors.columns)
formula = outcome + "~" + pred_sum

# %%
sns.scatterplot(x=df['internet_percent_pop'], y=df['co2_kg_dollar'])

# %%
df_model.corr()
# Out:
#                        co2_kg_dollar  internet_percent_pop  GDP_Ag_and_Forest  \
# co2_kg_dollar               1.000000              0.130521          -0.170392
# internet_percent_pop        0.130521              1.000000          -0.843380
# GDP_Ag_and_Forest          -0.170392             -0.843380           1.000000
# perc_renewable_energy      -0.217682              0.207353          -0.033256
#
#                        perc_renewable_energy
# co2_kg_dollar                      -0.217682
# internet_percent_pop                0.207353
# GDP_Ag_and_Forest                  -0.033256
# perc_renewable_energy               1.000000

# %%
model = ols(formula= formula, data=df_model).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          co2_kg_dollar   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     1.924
# Date:                Thu, 17 Oct 2019   Prob (F-statistic):              0.168
# Time:                        20:12:41   Log-Likelihood:                 31.599
# No. Observations:                 113   AIC:                            -59.20
# Df Residuals:                     111   BIC:                            -53.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                0.2417      0.045      5.349      0.000       0.152       0.331
# internet_percent_pop     0.0010      0.001      1.387      0.168      -0.000       0.002
# ==============================================================================
# Omnibus:                       41.229   Durbin-Watson:                   1.338
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.268
# Skew:                           1.464   Prob(JB):                     2.50e-20
# Kurtosis:                       6.255   Cond. No.                         162.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df[['gdp_capita', 'co2_kg_dollar']].corr()
# Out:
#                gdp_capita  co2_kg_dollar
# gdp_capita       1.000000       0.050769
# co2_kg_dollar    0.050769       1.000000

# %%
sns.scatterplot(x=df['gdp_capita'], y=df['internet_percent_pop'])

# %%
sns.scatterplot(x=df['rule_of_law'], y=df['internet_percent_pop'])

# %%
sns.scatterplot(x=df['GDP_Ag_and_Forest'], y=df['internet_percent_pop'])

# %%
sns.scatterplot(x=df['cost_of_biz'], y=df['internet_percent_pop'])

# %%
df_final = df[['internet_percent_pop', 'GDP_Ag_and_Forest', 'rule_of_law', 'gdp_capita', 'accountability', 'cost_of_biz']]

# %%
x_cols = ['GDP_Ag_and_Forest', 'rule_of_law', 'gdp_capita', 'accountability', 'cost_of_biz']

# %%
pd.plotting.scatter_matrix(df_final[x_cols], figsize=(10,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c180d1e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c175a2cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c18973eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c175e24a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c17d97940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c17dc7ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c17ce24e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c18c2cac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c18c2cb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c190dc630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c19109be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a2a81d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a2da780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a30bd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a34a320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c1a37a8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a3ace80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a3e9470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a418a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a44bfd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c1a4875c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a4bab70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a4f9160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a528710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1a55acc0>]],
#       dtype=object)

# %%
outcome = 'internet_percent_pop'
predictors = df_final.drop('internet_percent_pop', axis=1)
pred_sum = "+".join(predictors.columns)
formula = outcome + "~" + pred_sum

# %%
model = ols(formula= formula, data=df_final).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     internet_percent_pop   R-squared:                       0.807
# Model:                              OLS   Adj. R-squared:                  0.798
# Method:                   Least Squares   F-statistic:                     89.42
# Date:                  Thu, 17 Oct 2019   Prob (F-statistic):           1.37e-36
# Time:                          21:04:24   Log-Likelihood:                -426.11
# No. Observations:                   113   AIC:                             864.2
# Df Residuals:                       107   BIC:                             880.6
# Df Model:                             5
# Covariance Type:              nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            61.9950      2.716     22.825      0.000      56.611      67.379
# GDP_Ag_and_Forest    -1.2876      0.191     -6.744      0.000      -1.666      -0.909
# rule_of_law          10.6966      2.699      3.963      0.000       5.346      16.047
# gdp_capita            0.0003   8.66e-05      3.103      0.002    9.71e-05       0.000
# accountability       -2.1053      1.548     -1.360      0.177      -5.174       0.963
# cost_of_biz          -0.0785      0.071     -1.106      0.271      -0.219       0.062
# ==============================================================================
# Omnibus:                        4.021   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.134   Jarque-Bera (JB):                4.833
# Skew:                          -0.076   Prob(JB):                       0.0892
# Kurtosis:                       4.002   Cond. No.                     8.81e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.81e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
