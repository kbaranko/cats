# %%
import pandas as pd 
from pandas import ExcelWriter
from pandas import ExcelFile
import config
db_name = 'emissions_modelling'
import mysql.connector

# %%
df = pd.read_excel('wgidataset (1).xlsx', sheetname='Political StabilityNoViolence')
# Out:
# /Users/kylebaranko/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
df = df.drop(df.index[0:11])
df.head()
# Out:
#    Political Stability and Absence of Violence/Terrorism Unnamed: 1  \
# 11                                                NaN           NaN
# 12                                                NaN           NaN
# 13                                  Country/Territory          Code
# 14                                              Aruba           ABW
# 15                                            Andorra           ADO
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 11        NaN        NaN        NaN        NaN        NaN        NaN
# 12       1996       1996       1996       1996       1996       1996
# 13   Estimate     StdErr     NumSrc       Rank      Lower      Upper
# 14        NaN        NaN        NaN        NaN        NaN        NaN
# 15    1.17016   0.613507          1    89.3617    52.1277        100
#
#    Unnamed: 8 Unnamed: 9     ...      Unnamed: 112 Unnamed: 113 Unnamed: 114  \
# ...

# %%
df[['Political Stability and Absence of Violence/Terrorism', 'Unnamed: 104']]
# Out:
#     Political Stability and Absence of Violence/Terrorism Unnamed: 104
# 11                                                 NaN             NaN
# 12                                                 NaN            2016
# 13                                   Country/Territory        Estimate
# 14                                               Aruba          1.2842
# 15                                             Andorra         1.41342
# 16                                         Afghanistan        -2.67105
# 17                                              Angola       -0.315899
# 18                                            Anguilla         1.31534
# 19                                             Albania        0.344645
# 20                       Netherlands Antilles (former)             NaN
# 21                                United Arab Emirates        0.564749
# 22                                           Argentina        0.204626
# ...

# %%
df2016 = df[['Political Stability and Absence of Violence/Terrorism', 'Unnamed: 104']].copy()

# %%
new_header = df2016.iloc[1] #grab the first row for the header
df2016 = df2016[2:] #take the data less the header row
df2016.columns = new_header

# %%
new_header = df2016.iloc[0] #grab the first row for the header
df2016 = df2016[1:] #take the data less the header row
df2016.columns = new_header

# %%
df_stability = df2016

# %%
df_regulation = pd.read_excel('wgidataset (1).xlsx', sheetname='RegulatoryQuality')
# Out:
# /Users/kylebaranko/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
df_regulation.head(20)
# Out:
#                                    Regulatory Quality  \
# 0   Reflects perceptions of the ability of the gov...
# 1                                                 NaN
# 2                                              Legend
# 3                                            Estimate
# 4                                              StdErr
# 5                                              NumSrc
# 6                                                Rank
# 7                                               Lower
# 8                                               Upper
# 9                                                 NaN
# 10  The Worldwide Governance Indicators (WGI) are ...
# 11                                                NaN
# 12                                                NaN
# 13                                  Country/Territory
# 14                                              Aruba
# 15                                            Andorra
# ...

# %%
df_regulation = df_regulation.drop(df_regulation.index[0:12])
df_regulation.head()
# Out:
#    Regulatory Quality Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 12                NaN        NaN       1996       1996       1996       1996
# 13  Country/Territory       Code   Estimate     StdErr     NumSrc       Rank
# 14              Aruba        ABW        NaN        NaN        NaN        NaN
# 15            Andorra        ADO    1.26644    0.38636          1    88.0435
# 16        Afghanistan        AFG   -2.09033    0.38636          1    1.63043
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...      Unnamed: 112  \
# 12       1996       1996       1998       1998     ...              2017
# 13      Lower      Upper   Estimate     StdErr     ...            NumSrc
# 14        NaN        NaN        NaN        NaN     ...                 2
# 15    69.5652     98.913     1.3007   0.451397     ...                 1
# 16          0    5.97826   -2.08726   0.451397     ...                 9
#
# ...

# %%
df_regulation[['Regulatory Quality', 'Unnamed: 104']].head()
# Out:
#    Regulatory Quality Unnamed: 104
# 12                NaN         2016
# 13  Country/Territory     Estimate
# 14              Aruba      1.34755
# 15            Andorra     0.871443
# 16        Afghanistan     -1.32769

# %%
df_reg = df_regulation[['Regulatory Quality', 'Unnamed: 104']].copy()

# %%
df_reg.head()
# Out:
#    Regulatory Quality Unnamed: 104
# 12                NaN         2016
# 13  Country/Territory     Estimate
# 14              Aruba      1.34755
# 15            Andorra     0.871443
# 16        Afghanistan     -1.32769

# %%
df_reg.iloc[2]
# Out:
# Regulatory Quality      Aruba
# Unnamed: 104          1.34755
# Name: 14, dtype: object

# %%
new_header = df_reg.iloc[1] #grab the first row for the header
df_reg = df_reg[2:] #take the data less the header row
df_reg.columns = new_header

# %%
df_reg.head()
# Out:
# 13 Country/Territory  Estimate
# 14             Aruba   1.34755
# 15           Andorra  0.871443
# 16       Afghanistan  -1.32769
# 17            Angola  -1.00138
# 18          Anguilla  0.871443

# %%
len(df_reg)
# Out:
# 214

# %%
len(df_stability)
# Out:
# 214

# %%
df_stability.head()
# Out:
# 13 Country/Territory  Estimate
# 14             Aruba    1.2842
# 15           Andorra   1.41342
# 16       Afghanistan  -2.67105
# 17            Angola -0.315899
# 18          Anguilla   1.31534

# %%
df_reg.rename(columns = {'Estimate':'Regulatory_Quality'}, inplace = True)

# %%
df_stability.rename(columns = {'Estimate':'Political_Stability'}, inplace = True)

# %%
df_voice = pd.read_excel('wgidataset (1).xlsx', sheetname='VoiceandAccountability')
# Out:
# /Users/kylebaranko/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
df_voice = df_voice.drop(df_voice.index[0:12])
df_voice.head()
# Out:
#    Voice and Accountability Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 12                      NaN        NaN       1996       1996       1996
# 13        Country/Territory       Code   Estimate     StdErr     NumSrc
# 14                    Aruba        ABW        NaN        NaN        NaN
# 15                  Andorra        ADO    1.56322   0.291691          3
# 16              Afghanistan        AFG   -1.90854   0.261457          4
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...       \
# 12       1996       1996       1996       1998       1998     ...
# 13       Rank      Lower      Upper   Estimate     StdErr     ...
# 14        NaN        NaN        NaN        NaN        NaN     ...
# 15       98.5       81.5        100    1.52876   0.291445     ...
# 16          1          0        9.5    -2.0393    0.25609     ...
#
#    Unnamed: 112 Unnamed: 113 Unnamed: 114 Unnamed: 115 Unnamed: 116  \
# ...

# %%
df_voice = df_voice[['Voice and Accountability', 'Unnamed: 104']]

# %%
len(df_voice)
# Out:
# 216

# %%
new_header = df_voice.iloc[1] #grab the first row for the header
df_voice = df_voice[2:] #take the data less the header row
df_voice.columns = new_header

# %%
len(df_voice)
# Out:
# 214

# %%
df_voice.rename(columns = {'Estimate':'Voice/Accountability'}, inplace = True)

# %%
df_law = pd.read_excel('wgidataset (1).xlsx', sheetname='RuleofLaw')
# Out:
# /Users/kylebaranko/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
df_law = df_law.drop(df_law.index[0:12])
len(df_law)
# Out:
# 216

# %%
df_law = df_law[['Rule of Law', 'Unnamed: 104']]

# %%
new_header = df_law.iloc[1] #grab the first row for the header
df_law = df_law[2:] #take the data less the header row
df_law.columns = new_header

# %%
df_law.rename(columns = {'Estimate':'Rule_of_Law'}, inplace = True)
df_law.head()
# Out:
# 13 Country/Territory Rule_of_Law
# 14             Aruba     1.26174
# 15           Andorra     1.57792
# 16       Afghanistan    -1.49819
# 17            Angola    -1.08732
# 18          Anguilla  -0.0845851

# %%
df_combo = df_reg.merge(df_stability, how='inner', on='Country/Territory')

# %%
df_combo = df_combo.merge(df_voice, how='inner', on='Country/Territory')

# %%
df_combo = df_combo.merge(df_law, how='inner', on='Country/Territory')

# %%
df_combo.rename(columns = {'Country/Territory':'Country'}, inplace = True)

# %%
df_combo.rename(columns = {'Voice/Accountability':'Accountability'}, inplace = True)

# %% [markdown]
# ## df_combo.head()

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.passwd,
    database = db_name
)
cur = cnx.cursor()

# %%
tables_world_bank = {}
tables_world_bank['world_bank_index'] = (
    """CREATE TABLE world_bank_index (
       Country varchar(60),
       Regulatory_Quality float,
       Political_Stability float,
       Accountability float,
       Rule_of_Law float,
       PRIMARY KEY (Country))"""
)

# %%
tables_world_bank['world_bank_index']
# Out:
# 'CREATE TABLE world_bank_index (\n       Country varchar(60),\n       Regulatory_Quality float,\n       Political_Stability float,\n       Accountability float,\n       Rule_of_Law float,\n       PRIMARY KEY (Country))'

# %%
cur.execute(tables_world_bank['world_bank_index'])
cnx.commit()

# %%
len(df_combo)
# Out:
# 214

# %%
df_combo = df_combo.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
len(df_combo)
# Out:
# 202

# %%
def tuplify(df):
    tup_list = []
    
    for index, row in df.iterrows():
        tup = (row['Country'], 
               row['Regulatory_Quality'], 
               row['Political_Stability'], 
               row['Accountability'], 
               row['Rule_of_Law']
              ) # tuple length 7
        tup_list.append(tup)
    return tup_list

# %%
data = tuplify(df_combo)

# %%
data
# Out:
# [('Aruba',
#   1.34755277633667,
#   1.2841992378234863,
#   1.2793039083480835,
#   1.2617449760437012),
#  ('Andorra',
#   0.8714428544044495,
#   1.4134193658828735,
#   1.1765353679656982,
#   1.5779246091842651),
#  ('Afghanistan',
#   -1.3276876211166382,
#   -2.671053886413574,
#   -1.0398427248001099,
#   -1.4981898069381714),
#  ('Angola',
#   -1.0013797283172607,
#   -0.3158988356590271,
#   -1.1429325342178345,
#   -1.0873204469680786),
#  ('Albania',
#   0.18902206420898438,
#   0.3446446657180786,
#   0.1699492186307907,
#   -0.32886725664138794),
#  ('United Arab Emirates',
#   0.9725956320762634,
#   0.5647489428520203,
#   -1.0504213571548462,
#   0.8490409851074219),
#  ('Argentina',
#   -0.469625324010849,
#   0.20462550222873688,
#   0.49256306886672974,
#   -0.39360594749450684),
#  ('Armenia',
#   0.25005558133125305,
#   -0.662263810634613,
#   -0.5793346166610718,
#   -0.11912964284420013),
#  ('Antigua and Barbuda',
#   0.3414611518383026,
# ...

# %%
cnx.close()

# %%
stmt = "INSERT INTO world_bank_index (Country, Regulatory_Quality, Political_Stability, Accountability, Rule_of_Law) VALUES (%s, %s, %s, %s, %s)"
cur.executemany(stmt, data)

# %%
cnx.commit()

# %%
cnx.close()

# %%
df_combo.head()
# Out:
# 13      Country Regulatory_Quality Political_Stability Accountability  \
# 0         Aruba            1.34755              1.2842         1.2793
# 1       Andorra           0.871443             1.41342        1.17654
# 2   Afghanistan           -1.32769            -2.67105       -1.03984
# 3        Angola           -1.00138           -0.315899       -1.14293
# 5       Albania           0.189022            0.344645       0.169949
#
# 13 Rule_of_Law
# 0      1.26174
# 1      1.57792
# 2     -1.49819
# 3     -1.08732
# 5    -0.328867

# %%
df_ag = pd.read_excel('API_NV.AGR.TOTL.ZS_DS2_en_excel_v2_316750.xls', sheetname='Data')
# Out:
# /Users/kylebaranko/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
df.head()
# Out:
#          Data Source World Development Indicators  \
# 0  Last Updated Date          2019-10-16 00:00:00
# 1                NaN                          NaN
# 2       Country Name                 Country Code
# 3              Aruba                          ABW
# 4        Afghanistan                          AFG
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                     Indicator Name  Indicator Code
# 3  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 4  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df_ag = df_ag.drop(df_ag.index[0:2])
len(df_ag)
# Out:
# 265

# %%
df_ag.head()
# Out:
#     Data Source World Development Indicators  \
# 2  Country Name                 Country Code
# 3         Aruba                          ABW
# 4   Afghanistan                          AFG
# 5        Angola                          AGO
# 6       Albania                          ALB
#
#                                           Unnamed: 2      Unnamed: 3  \
# 2                                     Indicator Name  Indicator Code
# 3  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 4  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 5  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 6  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 2      1960.0      1961.0      1962.0      1963.0      1964.0      1965.0
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df_ag = df_ag[['Data Source', 'Unnamed: 60']]

# %%
df_ag['Unnamed: 60'] = df_ag['Unnamed: 60'].astype(str)

# %%
new_header = df_ag.iloc[0] #grab the first row for the header
df_ag = df_ag[1:] #take the data less the header row
df_ag.columns = new_header

# %%
df_ag.head()
# Out:
# 2 Country Name               2016.0
# 3        Aruba                  nan
# 4  Afghanistan   21.081086211038883
# 5       Angola    9.831168608692556
# 6      Albania    19.84997816607232
# 7      Andorra  0.49210138826415084

# %%
df_ag.rename(columns = {'Country Name':'country'}, inplace = True)
df_ag.rename(columns = {'2016.0': 'GDP_Ag_and_Forest'}, inplace = True)

# %%
df_ag.columns
# Out:
# Index(['country', 'GDP_Ag_and_Forest'], dtype='object', name=2)

# %%
df_ag.head()
# Out:
# 2      country    GDP_Ag_and_Forest
# 3        Aruba                  nan
# 4  Afghanistan   21.081086211038883
# 5       Angola    9.831168608692556
# 6      Albania    19.84997816607232
# 7      Andorra  0.49210138826415084

# %%
df_ag['GDP_Ag_and_Forest'] = df_ag['GDP_Ag_and_Forest'].astype(float)

# %%
df_oil = pd.read_excel('API_NY.GDP.PETR.RT.ZS_DS2_en_excel_v2_318824.xls', sheetname='Data')
# Out:
# /Users/kylebaranko/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
df_oil = df_oil.drop(df_oil.index[0:2])
df_oil = df_oil[['Data Source', 'Unnamed: 60']]
df_oil['Unnamed: 60'] = df_oil['Unnamed: 60'].astype(str)
new_header = df_oil.iloc[0] #grab the first row for the header
df_oil = df_oil[1:] #take the data less the header row
df_oil.columns = new_header

# %%
df_oil.head()
# Out:
# 2 Country Name                2016.0
# 3        Aruba                   0.0
# 4  Afghanistan  0.000824121640284273
# 5       Angola       10.168704920456
# 6      Albania     0.853420934523584
# 7      Andorra                   nan

# %%
df_oil.rename(columns = {'Country Name':'country'}, inplace = True)
df_oil.rename(columns = {'2016.0': 'petro_income'}, inplace = True)

# %%
df_oil.sort_values(by=['petro_income']).head()
# Out:
# 2             country petro_income
# 3               Aruba          0.0
# 158   North Macedonia          0.0
# 153          Maldives          0.0
# 147  Macao SAR, China          0.0
# 146            Latvia          0.0

# %%
df_resources = pd.read_excel('API_NY.GDP.TOTL.RT.ZS_DS2_en_excel_v2_317255.xls', sheetname='Data')
# Out:
# /Users/kylebaranko/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
df_resources
# Out:
#                                            Data Source  \
# 0                                    Last Updated Date
# 1                                                  NaN
# 2                                         Country Name
# 3                                                Aruba
# 4                                          Afghanistan
# 5                                               Angola
# 6                                              Albania
# 7                                              Andorra
# 8                                           Arab World
# 9                                 United Arab Emirates
# 10                                           Argentina
# 11                                             Armenia
# 12                                      American Samoa
# 13                                 Antigua and Barbuda
# 14                                           Australia
# 15                                             Austria
# ...

# %%
df_resources = df_resources.drop(df_resources.index[0:2])
df_resources = df_resources[['Data Source', 'Unnamed: 60']]
df_resources['Unnamed: 60'] = df_resources['Unnamed: 60'].astype(str)
new_header = df_resources.iloc[0] #grab the first row for the header
df_resources = df_resources[1:] #take the data less the header row
df_resources.columns = new_header

# %%
df_resources.head()
# Out:
# 2 Country Name              2016.0
# 3        Aruba  0.0035529819409617
# 4  Afghanistan   0.625859794776059
# 5       Angola    10.7462101426498
# 6      Albania    1.04950275059878
# 7      Andorra                 0.0

# %%
df_resources.rename(columns = {'Country Name':'country'}, inplace = True)
df_resources.rename(columns = {'2016.0': 'resource_income'}, inplace = True)

# %%
df_resources.head()
# Out:
# 2      country     resource_income
# 3        Aruba  0.0035529819409617
# 4  Afghanistan   0.625859794776059
# 5       Angola    10.7462101426498
# 6      Albania    1.04950275059878
# 7      Andorra                 0.0

# %%
df_endowment = df_ag.merge(df_oil, how='inner', on='country')
df_endowment = df_endowment.merge(df_resources, how='inner', on='country')

# %%
df_endowment.head()
# Out:
# 2      country  GDP_Ag_and_Forest          petro_income     resource_income
# 0        Aruba                NaN                   0.0  0.0035529819409617
# 1  Afghanistan          21.081086  0.000824121640284273   0.625859794776059
# 2       Angola           9.831169       10.168704920456    10.7462101426498
# 3      Albania          19.849978     0.853420934523584    1.04950275059878
# 4      Andorra           0.492101                   nan                 0.0

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.passwd,
    database = db_name
)
cur = cnx.cursor()

# %%
cnx.close()

# %%
tables_resources = {}
tables_resources['resource_data'] = (
    """CREATE TABLE resource_data (
       country varchar(60) ,
       GDP_Ag_and_Forest float,
       petro_income float,
       resource_income float,
       PRIMARY KEY (country))"""
)

# %%
tables_resources['resource_data']
# Out:
# 'CREATE TABLE resource_data (\n       country varchar(60) ,\n       GDP_Ag_and_Forest float,\n       petro_income float,\n       resource_income float,\n       PRIMARY KEY (country))'

# %%
cur.execute(tables_resources['resource_data'])
cnx.commit()

# %%
len(df_endowment)
# Out:
# 223

# %%
df_endowment['GDP_Ag_and_Forest'] = df_endowment['GDP_Ag_and_Forest'].astype(float)
df_endowment['petro_income'] = df_endowment['petro_income'].astype(float)
df_endowment['resource_income'] = df_endowment['resource_income'].astype(float)

# %%
df_endowment = df_endowment.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
def tuplify(df):
    tup_list = []
    
    for index, row in df.iterrows():
        tup = (row['country'], 
               row['GDP_Ag_and_Forest'], 
               row['petro_income'], 
               row['resource_income'] 
              ) # tuple length 7
        tup_list.append(tup)
    return tup_list

# %%
data1 = tuplify(df_endowment)

# %%
data1
# Out:
# [('Afghanistan', 21.081086211038883, 0.000824121640284273, 0.625859794776059),
#  ('Angola', 9.831168608692556, 10.168704920456, 10.7462101426498),
#  ('Albania', 19.84997816607232, 0.853420934523584, 1.04950275059878),
#  ('Arab World', 5.47819711648175, 12.817845752873781, 14.003865902891631),
#  ('United Arab Emirates',
#   0.7760545678620673,
#   10.8278815920281,
#   11.3466954259009),
#  ('Argentina', 6.264565820102544, 0.55245226765377, 1.13493944398007),
#  ('Armenia', 16.390473533849974, 0.0, 4.41207919314764),
#  ('Antigua and Barbuda', 1.5438279091989418, 0.0, 0.0),
#  ('Australia', 2.387301732440534, 0.172404207819285, 6.09512470308981),
#  ('Austria', 1.1127208669921667, 0.0234023877821888, 0.112891415219012),
#  ('Azerbaijan', 5.605111774557635, 13.1743924067352, 15.4401757366392),
#  ('Burundi', 30.645887638274004, 0.0, 17.0210559441359),
#  ('Belgium', 0.6349906159776376, 0.0, 0.0188058560498753),
# ...

# %%
stmt = "INSERT INTO resource_data (country, GDP_Ag_and_Forest, petro_income, resource_income) VALUES (%s, %s, %s, %s)"
cur.executemany(stmt, data1)

# %%
cnx.commit()

# %%
cnx.close()
