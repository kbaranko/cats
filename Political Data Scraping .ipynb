# %%
import requests 
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.theglobaleconomy.com/rankings/wb_political_stability/")
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')
children = list(soup.children)

# %%
children
# Out:
# ['html',
#  '\n',
#  <html lang="en" xml:lang="en" xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#  <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
#  <link href="https://www.theglobaleconomy.com/rankings/wb_political_stability/" rel="canonical"/>
#  <link href="https://www.theglobaleconomy.com/rankings/wb_political_stability/" hreflang="en" rel="alternate"/>
#  <link href="https://es.theglobaleconomy.com/rankings/wb_political_stability/" hreflang="es" rel="alternate"/>
#  <link href="https://de.theglobaleconomy.com/rankings/wb_political_stability/" hreflang="de" rel="alternate"/>
#  <link href="https://pt.theglobaleconomy.com/rankings/wb_political_stability/" hreflang="pt" rel="alternate"/>
#  <link href="https://ru.theglobaleconomy.com/rankings/wb_political_stability/" hreflang="ru" rel="alternate"/>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...

# %%
soup.find_all('div', attrs={'class':'outsideTitleElement'})
# Out:
# [<div class="outsideTitleElement">
#  <a id="Singapore"></a>
#  <span class="rankNumber" style="">1.</span>
#  <a class="graph_outside_link" href="/Monaco/wb_political_stability/" id="Monaco_l">Monaco</a>
#  </div>, <div class="outsideTitleElement">
#  <a id="Liechtenstein"></a>
#  <span class="rankNumber" style="">2.</span>
#  <a class="graph_outside_link" href="/New-Zealand/wb_political_stability/" id="New-Zealand_l">New Zealand</a>
#  </div>, <div class="outsideTitleElement">
#  <a id="Andorra"></a>
#  <span class="rankNumber" style="">3.</span>
#  <a class="graph_outside_link" href="/Singapore/wb_political_stability/" id="Singapore_l">Singapore</a>
#  </div>, <div class="outsideTitleElement">
#  <a id="Macao"></a>
#  <span class="rankNumber" style="">4.</span>
#  <a class="graph_outside_link" href="/Liechtenstein/wb_political_stability/" id="Liechtenstein_l">Liechtenstein</a>
#  </div>, <div class="outsideTitleElement">
#  <a id="Iceland"></a>
# ...
